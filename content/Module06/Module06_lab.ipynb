# %% [raw]
# # ASSIGNMENT CONFIG
#
# name: Module06_lab    # a name for the assignment (to validate that students submit to the correct autograder)
# config_file: null
# run_tests: true            # whether to run the assignment tests against the autograder notebook
# init_cell: false            # whether to include an Otter initialization cell in the output notebooks
# check_all_cell: false       # whether to include an Otter check-all cell in the output notebooks
# save_environment: false     # whether to save the student's environment in the log
# variables: null             # a mapping of variable names to type strings for serializing environments
# tests:                      # information about the structure and storage of tests
#   files: true               # whether to store tests in separate files, instead of the notebook metadata
#   ok_format: true           # whether the test cases are in OK-format (instead of the exception-based format)
#   url_prefix: null          # a URL prefix for where test files can be found for student use
# show_question_points: true  # whether to add the question point values to the last cell of each question
# runs_on: colab              # the interpreter this notebook (one of {'default', 'colab', 'jupyterlite'})
# export_cell: false          # whether to include an Otter export cell in the output notebooks
# files:
#   - cytokine_data.csv

# %%
# Setting up the Colab environment. DO NOT EDIT!
import os
import warnings
warnings.filterwarnings("ignore")

try:
    import otter

except ImportError:
    ! pip install -q otter-grader==4.0.0
    import otter

if not os.path.exists('walkthrough-tests'):
    zip_files = [f for f in os.listdir() if f.endswith('.zip')]
    assert len(zip_files)>0, 'Could not find any zip files!'
    assert len(zip_files)==1, 'Found multiple zip files!'
    ! unzip {zip_files[0]}

grader = otter.Notebook(colab=True,
                        tests_dir = 'walkthrough-tests')

# %% [markdown]
# # Lab
#
# Remember, all assignments are due at 11:59 PM (Philadelphia time) on the Sunday of each instructional week.

# %% [markdown]
# ## Learning Objectives
# At the end of this learning activity you will be able to:
#  - Practice creating statistical figures to answer biological questions.
#  - Practice writing figure legends for statistical figures.
#  - Practice writing descriptive reasonings about a figure.

# %% [markdown]
# **Note**: It is difficult to automatically grade figures as they are many "correct" answers.
# So, most questions will accept _any_ figure or axis and then ask you to answer a question that should be obvious from a properly generated figure.
# For all questions, assume a 95% interval.

# %% [markdown]
# --------------------------------------------

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('cytokine_data.csv')
data.head()
# Out:
#       Sex   Age     isAA     egf  eotaxin  fgfbasic    gcsf  gmcsf     hgf  \
# 0    Male  53.0  Checked   65.01   170.20     50.32  117.14   2.51  481.37
# 1  Female  62.0  Checked  232.83   118.23     36.03  215.38  24.53  988.71
# 2    Male  60.0  Checked   84.84    55.27     13.22   14.08   0.48  364.31
# 3    Male  62.0  Checked   24.13    70.18      4.12   14.08   1.33  510.36
# 4    Male  54.0  Checked  186.98    69.18     32.56  184.74  12.55  395.87
#
#    ifnalpha  ...     mig  mip1alpha  mip1beta  tnfalpha   vegf  cocaine_use  \
# 0    110.79  ...  185.29     104.63    151.15     17.61   7.54         True
# 1     66.13  ...  397.24     242.10    230.87     51.22  31.60         True
# 2     78.67  ...   18.63      34.85     68.34      2.48   0.84        False
# 3    118.64  ...  118.63     113.30     49.15     10.93   3.53         True
# 4     40.79  ...  140.56     131.83    241.00     32.01  10.81         True
#
# ...

# %% [markdown]
# ## Explore the effect of cocaine use on `mcp1`

# %% [raw]
# # BEGIN QUESTION
# name: q1_cocaine_use_spread
# manual: false
# points: 5

# %% [markdown]
# ### Q1: Do cocaine users have a higher level of expression of `mcp1`?

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 5  |
# | Public Checks | 2  |
# | Hidden Tests  | 1  |

# %% [raw]
# # BEGIN SOLUTION

# %%
# Generate a plot which displays the spread of mcp1 measurements across cocaine use
# BEGIN SOLUTION NO PROMPT

q1_plot = sns.stripplot(data = data,
                        x = 'cocaine_use',
                        y = 'mcp1')

q1_plot = sns.boxplot(data = data,
                      x = 'cocaine_use',
                      y = 'mcp1',
                      ax = q1_plot)

# END SOLUTION
""" # BEGIN PROMPT

q1_plot = ...

"""; # END PROMPT

# %% [markdown]
# Write a figure legend.
# At a minimum:
#  - Single declaritive sentence stating the conclusion of the figure.
#  - Each axis must be described.
#  - Every color, line, and dot must be described.
#  - Error bars must be described.

# %% [markdown]
# Do cocaine users or non-users have a higher levels of `mcp1`?

# %%
# Answer 'users' or 'non-users', 'same'
q1_higher_level = 'same' # SOLUTION

# %% [markdown]
# **Describe how you reached your conclusion from the graph.**

# %% [markdown]
# Answer:

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
print('Is q1_plot an Axes, FactGrid, or Figure:', isinstance(q1_plot, (plt.Axes, plt.Figure, sns.FacetGrid)))
# Out:
# Is q1_plot an Axes, FactGrid, or Figure: True

# %%
print('Is q1_higher_level in {"users", "non-users", "same"}:', q1_higher_level in {"users", "non-users", "same"})
# Out:
# Is q1_higher_level in {"users", "non-users", "same"}: True

# %%
# HIDDEN
print('q1_higher_level =', q1_higher_level)
# Out:
# q1_higher_level = same

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2_cocaine_use_mean
# manual: false
# points: 5

# %% [markdown]
# ### Q2: Do cocaine users or non-users have a higher _average_ level of `mcp1`?

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 5  |
# | Public Checks | 2  |
# | Hidden Tests  | 1  |

# %% [raw]
# # BEGIN SOLUTION

# %%
# Generate a plot which displays the confidence of the mean of mcp1 expression across cocaine use
# BEGIN SOLUTION NO PROMPT

q2_plot = sns.barplot(data = data,
                      x = 'cocaine_use',
                      y = 'mcp1')

# END SOLUTION
""" # BEGIN PROMPT

q2_plot = ...

"""; # END PROMPT

# %% [markdown]
# Write a figure legend.
# At a minimum:
#  - Single declaritive sentence stating the conclusion of the figure.
#  - Each axis must be described.
#  - Every color, line, and dot must be described.
#  - Error bars must be described.

# %% [markdown]
# Do cocaine users or non-users have a higher average level of mcp1?

# %%
# Answer 'users' or 'non-users', 'same'
q2_higher_mean = 'users' # SOLUTION

# %% [markdown]
# **Describe how you reached your conclusion from the graph.**

# %% [markdown]
# Answer:

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
print('Is q2_plot an Axes, FactGrid, or Figure:', isinstance(q2_plot, (plt.Axes, plt.Figure, sns.FacetGrid)))
# Out:
# Is q2_plot an Axes, FactGrid, or Figure: True

# %%
print('Is q2_higher_mean in {"users", "non-users", "same"}:', q2_higher_mean in {"users", "non-users", "same"})
# Out:
# Is q2_higher_mean in {"users", "non-users", "same"}: True

# %%
# HIDDEN
print('q2_higher_mean =', q2_higher_mean)
# Out:
# q2_higher_mean = users

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_cocaine_use_gender_mean
# manual: false
# points: 5

# %% [markdown]
# ### Q3: Does Sex impact the effect of cocaine use on the average level of `mcp1` expression?

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 5  |
# | Public Checks | 2  |
# | Hidden Tests  | 1  |

# %% [raw]
# # BEGIN SOLUTION

# %%
# Generate a plot which displays the confidence of the mean of mcp1 expression across cocaine use
# BEGIN SOLUTION NO PROMPT

q3_plot = sns.barplot(data = data,
                      x = 'cocaine_use',
                      y = 'mcp1',
                      hue = 'Sex')

# END SOLUTION
""" # BEGIN PROMPT

q3_plot = ...

"""; # END PROMPT

# %% [markdown]
# Write a figure legend.
# At a minimum:
#  - **A single declaritive sentence stating the conclusion of the figure.**
#  - Each axis must be described.
#  - Every color, line, and dot must be described.
#  - Error bars must be described.

# %%
# Is it 'likely' or 'unlikely' that gender has an impact on the effect of cocaine use on mcp1?
q3_gender_impact = 'unlikely' # SOLUTION

# %% [markdown]
# **Describe how you reached your conclusion from the graph.**

# %% [markdown]
# Answer:

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
print('Is q3_plot an Axes, FactGrid, or Figure:', isinstance(q3_plot, (plt.Axes, plt.Figure, sns.FacetGrid)))
# Out:
# Is q3_plot an Axes, FactGrid, or Figure: True

# %%
print('Is q3_gender_impact in {"likely", "unlikely"}:', q3_gender_impact in {"likely", "unlikely"})
# Out:
# Is q3_gender_impact in {"likely", "unlikely"}: True

# %%
# HIDDEN
print('q3_gender_impact =', q3_gender_impact)
# Out:
# q3_gender_impact = unlikely

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4_infection_length
# manual: false
# points: 5

# %% [markdown]
# ### Q4: Is there a correlation between infection length and `mcp1` expression?

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 5  |
# | Public Checks | 2  |
# | Hidden Tests  | 1  |

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
q4_plot = sns.lmplot(data=data,
                     x = 'years_infected',
                     y = 'mcp1')

# END SOLUTION
""" # BEGIN PROMPT

q4_plot = ...

"""; # END PROMPT

# %% [markdown]
# Write a figure legend.
# At a minimum:
#  - **Single declaritive sentence stating the conclusion of the figure.**
#  - Each axis must be described.
#  - Every color, line, and dot must be described.
#  - Error bars must be described.

# %%
# Is there a correlation between infection length and mcp1 expression? 'yes' or 'no'
q4_infection_length_corr = 'yes' # SOLUTION

# %% [markdown]
# **Describe how you reached your conclusion from the graph.**

# %% [markdown]
# Answer:

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
print('Is q4_plot an Axes, FactGrid, or Figure:', isinstance(q4_plot, (plt.Axes, plt.Figure, sns.FacetGrid)))
# Out:
# Is q4_plot an Axes, FactGrid, or Figure: True

# %%
print('Is q4_infection_length_corr in {"yes", "no"}:', q4_infection_length_corr in {"yes", "no"})
# Out:
# Is q4_infection_length_corr in {"yes", "no"}: True

# %%
# HIDDEN
print('q4_infection_length_corr =', q4_infection_length_corr)
# Out:
# q4_infection_length_corr = yes

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q5_infection_length_cocaine
# manual: false
# points: 5

# %% [markdown]
# ### Q5: Does cocaine use impact the correlation between infection length and `mcp1` expression?

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 5  |
# | Public Checks | 2  |
# | Hidden Tests  | 1  |

# %% [raw]
# # BEGIN SOLUTION

# %%
# Generate a plot which displays the confidence of the mean of mcp1 expression across cocaine use
# BEGIN SOLUTION NO PROMPT
q5_plot = sns.lmplot(data=data,
                     x = 'years_infected',
                     y = 'mcp1',
                     hue = 'cocaine_use')

# END SOLUTION
""" # BEGIN PROMPT

q5_plot = ...

"""; # END PROMPT

# %% [markdown]
# Write a figure legend.
# At a minimum:
#  - **A single declaritive sentence stating the conclusion of the figure.**
#  - Each axis must be described.
#  - Every color, line, and dot must be described.
#  - Error bars must be described.

# %%
# Does cocaine use impact the rate of mcp1 increase with infection length? 'yes' or 'no'
q5_infection_length_cocaine_slope = 'no' # SOLUTION

# %% [markdown]
# **Describe how you reached your conclusion from the graph.**

# %% [markdown]
# Answer:

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
print('Is q5_plot an Axes, FactGrid, or Figure:', isinstance(q5_plot, (plt.Axes, plt.Figure, sns.FacetGrid)))
# Out:
# Is q5_plot an Axes, FactGrid, or Figure: True

# %%
print('Is q5_infection_length_cocaine_slope in {"yes", "no"}:', q5_infection_length_cocaine_slope in {"yes", "no"})
# Out:
# Is q5_infection_length_cocaine_slope in {"yes", "no"}: True

# %%
# HIDDEN
print('q5_infection_length_cocaine_slope =', q5_infection_length_cocaine_slope)
# Out:
# q5_infection_length_cocaine_slope = no

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ## Submission
#
# Check:
#  - That all tables and graphs are rendered properly.
#  - Code completes without errors by using `Restart & Run All`.
#  - All checks **pass**.
#
# Then save the notebook and the `File` -> `Download` -> `Download .ipynb`. Upload this file to BBLearn.
