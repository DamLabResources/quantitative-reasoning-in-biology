# %% [raw]
# # ASSIGNMENT CONFIG
#
# name: Module01_walkthrough    # a name for the assignment (to validate that students submit to the correct autograder)
# config_file: null
# run_tests: true             # whether to run the assignment tests against the autograder notebook
# init_cell: false            # whether to include an Otter initialization cell in the output notebooks
# check_all_cell: false       # whether to include an Otter check-all cell in the output notebooks
# save_environment: false     # whether to save the student's environment in the log
# variables: null             # a mapping of variable names to type strings for serializing environments
# tests:                      # information about the structure and storage of tests
#   files: true               # whether to store tests in separate files, instead of the notebook metadata
#   ok_format: true           # whether the test cases are in OK-format (instead of the exception-based format)
#   url_prefix: null          # a URL prefix for where test files can be found for student use
# show_question_points: true  # whether to add the question point values to the last cell of each question
# runs_on: colab              # the interpreter this notebook (one of {'default', 'colab', 'jupyterlite'})
# export_cell: false          # whether to include an Otter export cell in the output notebooks

# %% [markdown]
# # Week 01 Walkthrough
#
# Remember, all assignments are due before the weekly synchronous session.

# %% [markdown]
# # Introduction

# %% [markdown]
# After completing this learning activity, you will be able to:
#  1. Launch Google Colab
#  2. Create text using Markdown.
#  3. Execute code cells.
#  4. Check your answers with the `Otter` grading system.
#  5. Submit assignments to BBLearn.

# %% [markdown]
# # Why Python

# %% [markdown]
# As we go through this course we will find that many biological questions can be framed as statistical visualizations and can be rigorously validated through statistical methods.
#
# While these have traditionally been done by hand or using spreadsheet software (like Excel) as biological datasets get larger and the questions get complex, these other tools become difficult and unwieldy. Python, on the other hand, is a generic programming language that is used to create anything. The recent explosion of research using Python for the biological and data science fields have spawned dozens of freely available software packages that allow you to take full advantage of the newest way to do things. Learning how to "program" will allow you to stay abreast of emerging techniques and technologies.

# %% [markdown]
# # Why Google Colab

# %% [markdown]
# I've been teaching "coding" in some form or another since 2007. There's one critical hurdle _everyone_ faces (including young me); I call it the **Step 0 Hurdle**.
#
# __How do you get Python installed?__
#
# Before you can even start learning, you need to have it. This used to be an arduous process that would take a skilled system administrator most of a day to do. There has been excellent progress on fixing some of these issues, but its still a bit difficult for an "average" person to do. Then there's the trouble of installing all of the tools we'll be using in the course. This hurdle is not insurmountable, by week 4 of this class all of you could do it, but it poses an incredible initial difficulty when you aren't even familiar with the concepts or decisions that you need to make during the installation process.
#
# Goolge Colab on the other hand is a free and browser based interface based off the Jupyter Notebook []. It comes "batteries included" with the vast majority of tools you'd ever use are already installed. By using this system, we can all have the same _environment_ thereby bypassing these initial stumbling blocks.

# %% [markdown]
# # Quick introduction on cells and blocks

# %% [markdown]
# A notebook is comprised of a series of `cells`.
#
# We'll use two basic flavors:
#  - Markdown
#  - Code
#
# Cell types can be changed using the dropdown menu at the top.

# %% [markdown]
# ## Markdown

# %% [markdown]
# Statistical analysis isn't all about math, code, and figures. Text is just as important. Jupyter/Colab use a plain-text syntax called [`Markdown`](https://www.markdownguide.org/basic-syntax/).
#
# Here are some brief examples:
#
# \*\*Bold text\*\* --> **Bold text**
#
# \*Italicized text\* --> *Italicized text*
#
# \*\*\*Bold & italicized text\*\*\* --> ***Bold & Italicized text***
#
# \`\`\`coding block\`\`\` --> ```coding block```
#
# \[A hyperlink\]\(https://www.google.com/) --> [A hyperlink](https://www.google.com/)

# %% [markdown]
# ---
# Some of these modifications can be found at the top-left hand corner of the text block. A complete list of Markdown syntax can be found [here](https://www.markdownguide.org/basic-syntax/).
#
# Markdown can also be used to create tables and lists. For example, by typing in the below text:
# ```markdown
# |Some|Table|
# |---|---|
# |X|Y|
# |Z|A|
# ```
# Creates the following table:
#
# |Some|Table|
# |---|---|
# | X | Y |
# | Z | A |
#
#
# Typing out this text:
# ```markdown
# 1. A
# 2. Numbered
# 3. List
#   * Bulleted
#   * Sublist
# ```
# creates the following list:
#
# 1. A
# 2. Numbered
# 3. List
#   * Bulleted
#   * Sublist
#
# A bulleted list can be created by typing in \* instead of numbers.
#
#
# Edit the next cell (by double clicking) to include your name.

# %% [markdown]
# ### Try me
#
# *Put your name here:*

# %% [markdown]
# Click on the next cell and hit `shift+return` to execute it.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# A Notebook's true power come from the fact that it is an easy interface to interact with a Python _kernel_. We do this through `code` cells.
#
# The Inferential Thinking Textbook summarized programming perfectly.
#
# ```
# In data science, the purpose of writing a program is to instruct a computer to carry out the steps of an analysis. Computers cannot study the world on their own. People must describe precisely what steps the computer should take in order to collect and analyze data, and those steps are expressed through programs.
# ```
# https://inferentialthinking.com/chapters/03/programming-in-python.html
#
#
# Code cells allow us to provide these programs to the computer.
#
# Click on the next cell and hit `shift+return` to execute it.

# %% [markdown]
# This `expression` printed the phrase "Hello world" to the output, which Jupyter/Colab then put underneath the cell. Try executing the next one. Also, notice that the number next to the cell changed. This is the `execution count` and tells you how many times ANY cell has been run.

# %%
5+4
# Out:
# 9

# %% [markdown]
# Notice, the result of the last line is printed to the screen.
# This is a particular feature of Jupyter Notebooks.
#
# If you need to see multiple results

# %%
print('first', 5+4, 'second', 12+1)
# Out:
# first 9 second 13

# %% [markdown]
# We can also use things called `variable`s to hold numbers (and other things) for use later. Try executing the next one.

# %%
height = 1.9 # meters
weight = 86 # kg

bmi = weight/height**2

# %% [markdown]
# Notice how it didn't output anything? That was because the last line didn't output anything. Instead it saved the value into the variable `bmi`. Type `bmi` into the next cell to see the answer.

# %%
print('BMI:', bmi)
# Out:
# BMI: 23.822714681440445

# %% [markdown]
# The nice thing about notebooks is their interactive nature. Go back and change the `height` and `weight` variables, execute __both__ cells, and see how the result changes.

# %% [markdown]
# # Otter Grader

# %% [markdown]
# In order to rigorously grade your coding we are going to use the [Otter Grader](https://otter-grader.readthedocs.io/en/latest/otter_check/index.html). A tool developed by educators at [UC Berkley](http://data8.org/). It allows me to create a set of _checks_ for each question, that you can run as you complete your assignment. This will help ensure that you are moving through the code correctly. I'll also use it to give suggestions for common mistakes.
#
# First, we need to do some _initializing_, these cells would normally be the first in the notebook. I've moved them down here to better describe them.
#
# This first cell unzips the file that you downloaded from BBLearn. And then installs the otter-grader tool. You only need to run this once, but it should be graceful if you accidentally do it twice.

# %%
# Setting up the Colab environment. DO NOT EDIT!
import os.path
import warnings
warnings.filterwarnings("ignore")

try:
    import otter

except ImportError:
    ! pip install -q otter-grader==4.0.0
    import otter


test_zip = "Week01-files.zip"
paths = [test_zip, 'walkthrough-tests', 'lab-tests', 'tests']
if not any(os.path.exists(p) for p in paths):
    raise EnvironmentError('NO OTTER FILES FOUND. Did you forget to upload them?')
elif os.path.exists('walkthrough-tests'):
    pass
elif os.path.exists(test_zip):
    ! unzip {test_zip}

grader = otter.Notebook(colab=True,
                        tests_dir = 'walkthrough-tests')

# %% [markdown]
# Now that we have the grader loaded. Let's take it for a spin with a simple problem.

# %% [markdown]
# ### Calculate a aerobic target heart rate?
#
# Consider a generally healthy 34 year old woman is looking to exercise in her ideal target heart rate.
# Per the [Mayo Clinic](https://www.mayoclinic.org/healthy-lifestyle/fitness/in-depth/exercise-intensity/art-20046887)
#
# ```
# How to determine your target heart rate zone
# Use an online calculator to determine your desired target heart rate zone. Or, here's a simple way to do the math yourself. If you're aiming for a target heart rate in the vigorous range of 70% to 85%, you can use the heart rate reserve (HRR) method to calculate it like this:
#
# Subtract your age from 220 to get your maximum heart rate.
# Calculate your resting heart rate by counting how many times your heart beats per minute when you are at rest, such as first thing in the morning. It's usually somewhere between 60 and 100 beats per minute for the average adult.
#  - Calculate your heart rate reserve (HRR) by subtracting your resting heart rate from your maximum heart rate.
#  - Multiply your HRR by 0.7 (70%). Add your resting heart rate to this number.
#  - Multiply your HRR by 0.85 (85%). Add your resting heart rate to this number.
#  - These two numbers are your average target heart rate zone for vigorous exercise intensity when using the HRR to calculate your heart rate. Your heart rate during vigorous exercise should generally be between these two numbers.
# ```
#
# Our subject estimates her resting heart rate at 60 bp.

# %% [markdown]
# ### Q1: Using the information above, calculate the subject's heart rate reserve.
#
# You can see that your solution should finish the expression:
#
# ```
# heart_rate_reserve = ...
# ```
#
# You can take as many lines as you need to solve the problem (and in the future, there will be many lines needed).
# That being said, the answer __MUST__ be in the variable `heart_rate_reserve` for it to count.
# The _checks_ will help to ensure not only that you've saved it right, but it is the right `type`.

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 2  |
# | Public Checks | 3  |
# | Hidden Tests  | 0  |

# %% [raw]
# # BEGIN QUESTION
# name: q1_resting_rate
# manual: false
# points: 2

# %% [raw]
# # BEGIN SOLUTION

# %%
resting_heart_rate = 60
age = 34

heart_rate_reserve = 220 - age - resting_heart_rate # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(heart_rate_reserve, int)
# Out:
# True

# %%
(heart_rate_reserve  < 220) & (heart_rate_reserve > 0)
# Out:
# True

# %%
heart_rate_reserve
# Out:
# 126

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ### Q3: Using the information above, calculate the upper limit of the subject's target heart rate zone.

# %% [markdown]
# |               |    |
# | --------------|----|
# | Points        | 2  |
# | Public Checks | 3  |
# | Hidden Tests  | 0  |

# %% [raw]
# # BEGIN QUESTION
# name: q3_upper_limit
# manual: false
# points: 2

# %% [raw]
# # BEGIN SOLUTION

# %%
upper_target_zone = heart_rate_reserve*0.85 + resting_heart_rate # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(upper_target_zone, float)
# Out:
# True

# %%
(upper_target_zone  < 220) & (upper_target_zone > 0)
# Out:
# True

# %%
f'upper_target_zone = {upper_target_zone:0.1f}'
# Out:
# 'upper_target_zone = 167.1'

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# # Submissions

# %% [markdown]
# Lastly, how do you submit your assignment?
#
# At the very end of all assignments. There will be a `check_all` function. Use a `Restart & Run All` to validate that your code still works (we'll talk more about this in the future), Then, use the `File` -> `Download` -> `Download .ipynb`. That file, is your notebook. You can open it up in something like Notepad (not Word) and you'll see your code, plus some extra formatting.
#
# This `.ipynb` file is what you'll upload to BBLearn.

# %%
grader.check_all()
